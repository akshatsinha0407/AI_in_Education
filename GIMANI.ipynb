# %% [markdown]
# <a href="https://colab.research.google.com/github/akshatsinha0407/AI_in_Education/blob/main/GIMANI.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -q --upgrade google-generativeai

# %%
import google.generativeai as genai

genai.configure(api_key="AIzaSyAq5_8yRPhjhw5gQdXyjJE4fdNQ-Xuz9Gc")

# %%
try:
    model = genai.GenerativeModel("models/gemini-2.5-flash")
    response = model.generate_content("AIzaSyAq5_8yRPhjhw5gQdXyjJE4fdNQ-Xuz9Gc")

    print("API Key is VALID ✅")
    print("Response:", response.text)

except Exception as e:
    print("API Key FAILED ❌")
    print("Error:", e)
# Out:
# API Key is VALID ✅
# Response: That looks like a **Google API Key**.
#
# **It is extremely important that you keep this key private and do not share it publicly.**
#
# If this key is exposed, malicious actors could potentially use it to:
# *   Incur significant charges on your Google Cloud account by making requests to various Google APIs (e.g., Maps, Vision, Translate).
# *   Access or manipulate data if the key is not properly restricted.
#
# **Recommendations:**
# 1.  **Do NOT hardcode API keys in client-side code or public repositories (like GitHub).**
# 2.  **Restrict the key's usage:**
#     *   Limit it to specific APIs that your application needs.
#     *   Restrict it by IP address, HTTP referrer (for web apps), or Android/iOS app bundle ID.
# 3.  **Rotate your keys regularly**, especially if you suspect one has been compromised.
# 4.  For server-to-server interactions, consider using **service accounts** instead of API keys for better security.
#
# ...
